# %% [markdown]
# ## <font color=blue>Diabetes dataset age 0-30<font>
# [Baseline Categorical](#SVM)
#
# [One Hot](#hot)

# %%
# %matplotlib notebook
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import accuracy_score, precision_score, recall_score, \
f1_score, confusion_matrix, classification_report
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.svm import LinearSVC, SVC
from tqdm import tqdm

# %%
def plot_confusion(clf, title, X_test, y_test):
    svm_predicted_mc = clf.predict(X_test)
    confusion_mc = confusion_matrix(y_test, svm_predicted_mc)
    df_cm = pd.DataFrame(confusion_mc, 
                         index = [i for i in range(0,3)], columns = [i for i in range(0,3)])

    plt.figure(figsize=(6,4))
    ax_ticks= ['<30', '>30', 'NO']
    sns.heatmap(df_cm, annot=True, xticklabels=ax_ticks, yticklabels=ax_ticks, fmt='g')
    plt.title(title + '\nAccuracy:{0:.3f}'.format(accuracy_score(y_test, 
                                                                           svm_predicted_mc)))
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    
    print('Micro-averaged precision = {:.2f} (treat instances equally)'
      .format(precision_score(y_test, svm_predicted_mc, average = 'micro')))
    print('Macro-averaged precision = {:.2f} (treat classes equally)'
      .format(precision_score(y_test, svm_predicted_mc, average = 'macro')))
    print('Micro-averaged f1 = {:.2f} (treat instances equally)'
          .format(f1_score(y_test, svm_predicted_mc, average = 'micro')))
    print('Macro-averaged f1 = {:.2f} (treat classes equally)'
          .format(f1_score(y_test, svm_predicted_mc, average = 'macro')))
    print(classification_report(y_test, svm_predicted_mc, target_names=ax_ticks))

# %%
# df = pd.read_csv("diabetic_data.csv", dtype='category').iloc[:500,2:]
df = pd.read_csv("diabetic_data.csv", dtype='category').iloc[:,2:]
df.shape
# Out:
# (101766, 48)

# %%
df['age'].head(2)
# Out:
# 0     [0-10)
# 1    [10-20)
# Name: age, dtype: category
# Categories (10, object): [[0-10), [10-20), [20-30), [30-40), ..., [60-70), [70-80), [80-90), [90-100)]

# %%
df = df.loc[(df['age'] == '[0-10)')| (df['age'] == '[20-30)') | (df['age'] == '[10-20)')]
# df = df.loc[(df['age'] == '[0-10)')| (df['age'] == '[20-30)')]

# %%
df.head(2)
# Out:
#         race  gender      age weight admission_type_id  \
# 0  Caucasian  Female   [0-10)      ?                 6
# 1  Caucasian  Female  [10-20)      ?                 1
#
#   discharge_disposition_id admission_source_id time_in_hospital payer_code  \
# 0                       25                   1                1          ?
# 1                        1                   7                3          ?
#
#           medical_specialty    ...     citoglipton insulin  \
# 0  Pediatrics-Endocrinology    ...              No      No
# 1                         ?    ...              No      Up
#
#   glyburide-metformin glipizide-metformin glimepiride-pioglitazone  \
# 0                  No                  No                       No
# 1                  No                  No                       No
#
#   metformin-rosiglitazone metformin-pioglitazone change diabetesMed readmitted
# 0                      No                     No     No          No         NO
# 1                      No                     No     Ch         Yes        >30
#
# [2 rows x 48 columns]

# %%
df.describe()
# Out:
#              race  gender      age weight admission_type_id  \
# count        2509    2509     2509   2509              2509
# unique          6       2        3      8                 8
# top     Caucasian  Female  [20-30)      ?                 1
# freq         1549    1599     1657   2417              1488
#
#        discharge_disposition_id admission_source_id time_in_hospital  \
# count                      2509                2509             2509
# unique                       18                  11               14
# top                           1                   7                2
# freq                       2175                1521              681
#
#        payer_code medical_specialty    ...     citoglipton insulin  \
# count        2509              2509    ...            2509    2509
# unique         14                47    ...               1       4
# top             ?                 ?    ...              No  Steady
# freq         1222               998    ...            2509     912
#
#        glyburide-metformin glipizide-metformin glimepiride-pioglitazone  \
# count                 2509                2509                     2509
# unique                   1                   1                        1
# top                     No                  No                       No
# freq                  2509                2509                     2509
#
#        metformin-rosiglitazone metformin-pioglitazone change diabetesMed  \
# count                     2509                   2509   2509        2509
# unique                       1                      1      2           2
# top                         No                     No     No         Yes
# freq                      2509                   2509   1350        2048
#
#        readmitted
# count        2509
# unique          3
# top            NO
# freq         1470
#
# [4 rows x 48 columns]

# %%
def show_unique(dataF):
    for c in dataF.columns:
        print(c, dataF[c].unique())
        print('*'*50)

show_unique(df)
# Out:
# race [Caucasian, AfricanAmerican, Other, Hispanic, ?, Asian]
# Categories (6, object): [Caucasian, AfricanAmerican, Other, Hispanic, ?, Asian]
# **************************************************
# gender [Female, Male]
# Categories (2, object): [Female, Male]
# **************************************************
# age [[0-10), [10-20), [20-30)]
# Categories (3, object): [[0-10), [10-20), [20-30)]
# **************************************************
# weight [?, [0-25), [25-50), [50-75), [100-125), [75-100), [125-150), [150-175)]
# Categories (8, object): [?, [0-25), [25-50), [50-75), [100-125), [75-100), [125-150), [150-175)]
# **************************************************
# admission_type_id [6, 1, 2, 3, 5, 8, 4, 7]
# Categories (8, object): [6, 1, 2, 3, 5, 8, 4, 7]
# **************************************************
# discharge_disposition_id [25, 1, 5, 6, 11, ..., 4, 23, 28, 13, 9]
# Length: 18
# Categories (18, object): [25, 1, 5, 6, ..., 23, 28, 13, 9]
# **************************************************
# admission_source_id [1, 7, 2, 6, 20, ..., 17, 3, 9, 5, 11]
# Length: 11
# Categories (11, object): [1, 7, 2, 6, ..., 3, 9, 5, 11]
# **************************************************
# time_in_hospital [1, 3, 2, 10, 5, ..., 11, 9, 8, 12, 14]
# Length: 14
# Categories (14, object): [1, 3, 2, 10, ..., 9, 8, 12, 14]
# **************************************************
# payer_code [?, UN, MD, HM, DM, ..., CP, OG, CM, WC, CH]
# Length: 14
# Categories (14, object): [?, UN, MD, HM, ..., OG, CM, WC, CH]
# **************************************************
# medical_specialty [Pediatrics-Endocrinology, ?, Gastroenterology, Family/GeneralPractice, Pediatrics, ..., Gynecology, SurgicalSpecialty, Radiologist, Surgeon, Endocrinology-Metabolism]
# Length: 47
# Categories (47, object): [Pediatrics-Endocrinology, ?, Gastroenterology, Family/GeneralPractice, ..., SurgicalSpecialty, Radiologist, Surgeon, Endocrinology-Metabolism]
# **************************************************
# num_lab_procedures [41, 59, 11, 53, 51, ..., 84, 95, 132, 91, 101]
# Length: 102
# Categories (102, object): [41, 59, 11, 53, ..., 95, 132, 91, 101]
# **************************************************
# num_procedures [0, 5, 1, 4, 3, 2, 6]
# Categories (7, object): [0, 5, 1, 4, 3, 2, 6]
# **************************************************
# num_medications [1, 18, 13, 20, 4, ..., 29, 39, 36, 38, 41]
# Length: 43
# Categories (43, object): [1, 18, 13, 20, ..., 39, 36, 38, 41]
# **************************************************
# number_outpatient [0, 2, 1, 7, 9, ..., 6, 10, 8, 12, 11]
# Length: 14
# Categories (14, object): [0, 2, 1, 7, ..., 10, 8, 12, 11]
# **************************************************
# number_emergency [0, 1, 2, 8, 3, ..., 5, 6, 7, 9, 13]
# Length: 11
# Categories (11, object): [0, 1, 2, 8, ..., 6, 7, 9, 13]
# **************************************************
# number_inpatient [0, 1, 3, 2, 5, ..., 15, 16, 21, 18, 19]
# Length: 21
# Categories (21, object): [0, 1, 3, 2, ..., 16, 21, 18, 19]
# **************************************************
# diag_1 [250.83, 276, 648, 277, 250.11, ..., 647, 283, 625, 333, 475]
# Length: 265
# Categories (265, object): [250.83, 276, 648, 277, ..., 283, 625, 333, 475]
# **************************************************
# diag_2 [?, 250.01, 250, 250.02, V15, ..., 813, 338, E917, 652, 586]
# Length: 281
# Categories (281, object): [?, 250.01, 250, 250.02, ..., 338, E917, 652, 586]
# **************************************************
# diag_3 [?, 255, V27, 263, 724, ..., 958, E849, V46, 711, 812]
# Length: 304
# Categories (304, object): [?, 255, V27, 263, ..., E849, V46, 711, 812]
# **************************************************
# number_diagnoses [1, 9, 6, 3, 2, 8, 4, 5, 7, 14]
# Categories (10, object): [1, 9, 6, 3, ..., 4, 5, 7, 14]
# **************************************************
# max_glu_serum [None, >300, >200, Norm]
# Categories (4, object): [None, >300, >200, Norm]
# **************************************************
# A1Cresult [None, >8, >7, Norm]
# Categories (4, object): [None, >8, >7, Norm]
# **************************************************
# metformin [No, Steady, Up, Down]
# Categories (4, object): [No, Steady, Up, Down]
# **************************************************
# repaglinide [No, Steady, Up]
# Categories (3, object): [No, Steady, Up]
# **************************************************
# nateglinide [No, Steady]
# Categories (2, object): [No, Steady]
# **************************************************
# chlorpropamide [No]
# Categories (1, object): [No]
# **************************************************
# glimepiride [No, Steady, Down, Up]
# Categories (4, object): [No, Steady, Down, Up]
# **************************************************
# acetohexamide [No]
# Categories (1, object): [No]
# **************************************************
# glipizide [No, Steady, Down, Up]
# Categories (4, object): [No, Steady, Down, Up]
# **************************************************
# glyburide [No, Steady, Up]
# Categories (3, object): [No, Steady, Up]
# **************************************************
# tolbutamide [No]
# Categories (1, object): [No]
# **************************************************
# pioglitazone [No, Steady, Up, Down]
# Categories (4, object): [No, Steady, Up, Down]
# **************************************************
# rosiglitazone [No, Up, Steady, Down]
# Categories (4, object): [No, Up, Steady, Down]
# **************************************************
# acarbose [No, Steady]
# Categories (2, object): [No, Steady]
# **************************************************
# miglitol [No]
# Categories (1, object): [No]
# **************************************************
# troglitazone [No]
# Categories (1, object): [No]
# **************************************************
# tolazamide [No]
# Categories (1, object): [No]
# **************************************************
# examide [No]
# Categories (1, object): [No]
# **************************************************
# citoglipton [No]
# Categories (1, object): [No]
# **************************************************
# insulin [No, Up, Down, Steady]
# Categories (4, object): [No, Up, Down, Steady]
# **************************************************
# glyburide-metformin [No]
# Categories (1, object): [No]
# **************************************************
# glipizide-metformin [No]
# Categories (1, object): [No]
# **************************************************
# glimepiride-pioglitazone [No]
# Categories (1, object): [No]
# **************************************************
# metformin-rosiglitazone [No]
# Categories (1, object): [No]
# **************************************************
# metformin-pioglitazone [No]
# Categories (1, object): [No]
# **************************************************
# change [No, Ch]
# Categories (2, object): [No, Ch]
# **************************************************
# diabetesMed [No, Yes]
# Categories (2, object): [No, Yes]
# **************************************************
# readmitted [NO, >30, <30]
# Categories (3, object): [NO, >30, <30]
# **************************************************

# %% [markdown]
# ### <font color =blue>1. remove columns with missing data</font>

# %%
df = df.drop(columns=['weight', 'payer_code', 'medical_specialty'])
df.head(2)
# Out:
#         race  gender      age admission_type_id discharge_disposition_id  \
# 0  Caucasian  Female   [0-10)                 6                       25
# 1  Caucasian  Female  [10-20)                 1                        1
#
#   admission_source_id time_in_hospital num_lab_procedures num_procedures  \
# 0                   1                1                 41              0
# 1                   7                3                 59              0
#
#   num_medications    ...     citoglipton insulin glyburide-metformin  \
# 0               1    ...              No      No                  No
# 1              18    ...              No      Up                  No
#
#   glipizide-metformin glimepiride-pioglitazone metformin-rosiglitazone  \
# 0                  No                       No                      No
# 1                  No                       No                      No
#
#   metformin-pioglitazone change diabetesMed readmitted
# 0                     No     No          No         NO
# 1                     No     Ch         Yes        >30
#
# [2 rows x 45 columns]

# %% [markdown]
# ### <font color=blue> 2. remove incomplete columns and rows </font>

# %%
# drop missing values
df = df.replace('?', np.nan)
df = df.replace('Unknown/Invalid', np.nan)
df = df.dropna()
df.shape
# Out:
# (2009, 45)

# %%
df = df.drop(columns= df.columns[df.nunique() == 1])

# %%
show_unique(df)
# Out:
# race [Caucasian, AfricanAmerican, Other, Hispanic, Asian]
# Categories (5, object): [Caucasian, AfricanAmerican, Other, Hispanic, Asian]
# **************************************************
# gender [Female, Male]
# Categories (2, object): [Female, Male]
# **************************************************
# age [[10-20), [20-30), [0-10)]
# Categories (3, object): [[10-20), [20-30), [0-10)]
# **************************************************
# admission_type_id [1, 2, 6, 3, 5, 8, 4, 7]
# Categories (8, object): [1, 2, 6, 3, 5, 8, 4, 7]
# **************************************************
# discharge_disposition_id [1, 25, 6, 11, 7, ..., 4, 23, 28, 13, 9]
# Length: 18
# Categories (18, object): [1, 25, 6, 11, ..., 23, 28, 13, 9]
# **************************************************
# admission_source_id [7, 2, 1, 6, 20, ..., 4, 3, 9, 5, 11]
# Length: 11
# Categories (11, object): [7, 2, 1, 6, ..., 3, 9, 5, 11]
# **************************************************
# time_in_hospital [3, 2, 10, 1, 5, ..., 11, 9, 8, 12, 14]
# Length: 14
# Categories (14, object): [3, 2, 10, 1, ..., 9, 8, 12, 14]
# **************************************************
# num_lab_procedures [59, 11, 53, 56, 35, ..., 84, 95, 132, 91, 101]
# Length: 102
# Categories (102, object): [59, 11, 53, 56, ..., 95, 132, 91, 101]
# **************************************************
# num_procedures [0, 5, 1, 4, 3, 2, 6]
# Categories (7, object): [0, 5, 1, 4, 3, 2, 6]
# **************************************************
# num_medications [18, 13, 20, 4, 12, ..., 29, 39, 36, 38, 41]
# Length: 43
# Categories (43, object): [18, 13, 20, 4, ..., 39, 36, 38, 41]
# **************************************************
# number_outpatient [0, 2, 1, 7, 9, ..., 6, 10, 8, 12, 11]
# Length: 14
# Categories (14, object): [0, 2, 1, 7, ..., 10, 8, 12, 11]
# **************************************************
# number_emergency [0, 1, 2, 8, 3, ..., 5, 7, 9, 6, 13]
# Length: 11
# Categories (11, object): [0, 1, 2, 8, ..., 7, 9, 6, 13]
# **************************************************
# number_inpatient [0, 1, 3, 2, 5, ..., 15, 16, 21, 18, 19]
# Length: 20
# Categories (20, object): [0, 1, 3, 2, ..., 16, 21, 18, 19]
# **************************************************
# diag_1 [276, 648, 277, 250.13, 70, ..., 647, 283, 625, 333, 475]
# Length: 254
# Categories (254, object): [276, 648, 277, 250.13, ..., 283, 625, 333, 475]
# **************************************************
# diag_2 [250.01, 250, 250.02, V15, 276, ..., 813, 338, E917, 652, 586]
# Length: 265
# Categories (265, object): [250.01, 250, 250.02, V15, ..., 338, E917, 652, 586]
# **************************************************
# diag_3 [255, V27, 263, 724, 753, ..., 958, E849, V46, 711, 812]
# Length: 301
# Categories (301, object): [255, V27, 263, 724, ..., E849, V46, 711, 812]
# **************************************************
# number_diagnoses [9, 6, 3, 8, 4, 5, 7, 14]
# Categories (8, object): [9, 6, 3, 8, 4, 5, 7, 14]
# **************************************************
# max_glu_serum [None, >300, >200, Norm]
# Categories (4, object): [None, >300, >200, Norm]
# **************************************************
# A1Cresult [None, >8, >7, Norm]
# Categories (4, object): [None, >8, >7, Norm]
# **************************************************
# metformin [No, Steady, Up, Down]
# Categories (4, object): [No, Steady, Up, Down]
# **************************************************
# repaglinide [No, Steady, Up]
# Categories (3, object): [No, Steady, Up]
# **************************************************
# nateglinide [No, Steady]
# Categories (2, object): [No, Steady]
# **************************************************
# glimepiride [No, Steady, Down]
# Categories (3, object): [No, Steady, Down]
# **************************************************
# glipizide [No, Steady, Down, Up]
# Categories (4, object): [No, Steady, Down, Up]
# **************************************************
# glyburide [No, Steady, Up]
# Categories (3, object): [No, Steady, Up]
# **************************************************
# pioglitazone [No, Steady, Down, Up]
# Categories (4, object): [No, Steady, Down, Up]
# **************************************************
# rosiglitazone [No, Up, Steady, Down]
# Categories (4, object): [No, Up, Steady, Down]
# **************************************************
# acarbose [No, Steady]
# Categories (2, object): [No, Steady]
# **************************************************
# insulin [Up, No, Down, Steady]
# Categories (4, object): [Up, No, Down, Steady]
# **************************************************
# change [Ch, No]
# Categories (2, object): [Ch, No]
# **************************************************
# diabetesMed [Yes, No]
# Categories (2, object): [Yes, No]
# **************************************************
# readmitted [>30, NO, <30]
# Categories (3, object): [>30, NO, <30]
# **************************************************

# %% [markdown]
# ### <font color = blue>3. categorical variables</font>

# %%
to_num = ['time_in_hospital', 'num_lab_procedures', 'num_procedures',
         'num_medications', 'number_outpatient', 'number_emergency',
         'number_inpatient', 'number_diagnoses']

to_cat_codes = list(set(df.columns) - set(to_num))

# %%
X_features = list(to_num)
for c in to_cat_codes:
    df[c+'_cat'] = df[c].cat.codes        
    X_features += [c+'_cat']
    
X_features.remove('readmitted_cat')
X_features
# Out:
# ['time_in_hospital',
#  'num_lab_procedures',
#  'num_procedures',
#  'num_medications',
#  'number_outpatient',
#  'number_emergency',
#  'number_inpatient',
#  'number_diagnoses',
#  'metformin_cat',
#  'change_cat',
#  'age_cat',
#  'max_glu_serum_cat',
#  'race_cat',
#  'A1Cresult_cat',
#  'gender_cat',
#  'admission_source_id_cat',
#  'glyburide_cat',
#  'diag_3_cat',
#  'glimepiride_cat',
#  'repaglinide_cat',
#  'pioglitazone_cat',
#  'acarbose_cat',
#  'nateglinide_cat',
#  'insulin_cat',
#  'diag_2_cat',
#  'diabetesMed_cat',
#  'admission_type_id_cat',
#  'rosiglitazone_cat',
#  'diag_1_cat',
#  'glipizide_cat',
#  'discharge_disposition_id_cat']

# %%
df['readmitted'].head(11)
# Out:
# 1      >30
# 2       NO
# 28     >30
# 128    >30
# 143    >30
# 191     NO
# 199    >30
# 204     NO
# 232    <30
# 258     NO
# 270     NO
# Name: readmitted, dtype: category
# Categories (3, object): [<30, >30, NO]

# %%
df['readmitted_cat'].head(11)
# Out:
# 1      1
# 2      2
# 28     1
# 128    1
# 143    1
# 191    2
# 199    1
# 204    2
# 232    0
# 258    2
# 270    2
# Name: readmitted_cat, dtype: int8

# %% [markdown]
# #### <font color=red>Target Mapping: < 30 = 0, >30 = 1, NO = 2, </font>

# %% [markdown]
# ### <font color=blue>4. split</font>

# %%
for n in to_num:
    df[n] = df[n].astype('int')

df[to_num].dtypes
# Out:
# time_in_hospital      int64
# num_lab_procedures    int64
# num_procedures        int64
# num_medications       int64
# number_outpatient     int64
# number_emergency      int64
# number_inpatient      int64
# number_diagnoses      int64
# dtype: object

# %% [markdown]
# ## <font color=green>to Categorical</font>

# %%
X_train, X_test, y_train, y_test = train_test_split(
    df[X_features], df['readmitted_cat'] , random_state = 0)

# %%
X_train.head(2)
# Out:
#        time_in_hospital  num_lab_procedures  num_procedures  num_medications  \
# 56340                 7                  83               6               33
# 88061                11                  68               2               12
#
#        number_outpatient  number_emergency  number_inpatient  \
# 56340                  0                 0                 0
# 88061                  0                 0                 1
#
#        number_diagnoses  metformin_cat  change_cat  \
# 56340                 9              1           0
# 88061                 5              1           0
#
#                    ...               acarbose_cat  nateglinide_cat  \
# 56340              ...                          0                0
# 88061              ...                          0                0
#
#        insulin_cat  diag_2_cat  diabetesMed_cat  admission_type_id_cat  \
# 56340            0         282                1                      0
# 88061            3         372                1                      0
#
#        rosiglitazone_cat  diag_1_cat  glipizide_cat  \
# 56340                  1         190              1
# 88061                  1          73              1
#
#        discharge_disposition_id_cat
# 56340                             0
# 88061                             0
#
# [2 rows x 31 columns]

# %%
y_train.head(2)
# Out:
# 56340    2
# 88061    1
# Name: readmitted_cat, dtype: int8

# %%
X_test.head(2)
# Out:
#        time_in_hospital  num_lab_procedures  num_procedures  num_medications  \
# 95141                 4                  66               0               14
# 6136                  2                  47               1               11
#
#        number_outpatient  number_emergency  number_inpatient  \
# 95141                  0                 0                 0
# 6136                   0                 0                 0
#
#        number_diagnoses  metformin_cat  change_cat  \
# 95141                 5              1           0
# 6136                  9              1           1
#
#                    ...               acarbose_cat  nateglinide_cat  \
# 95141              ...                          0                0
# 6136               ...                          0                0
#
#        insulin_cat  diag_2_cat  diabetesMed_cat  admission_type_id_cat  \
# 95141            0          86                1                      0
# 6136             1         313                0                      1
#
#        rosiglitazone_cat  diag_1_cat  glipizide_cat  \
# 95141                  1         308              1
# 6136                   1         347              1
#
#        discharge_disposition_id_cat
# 95141                             0
# 6136                              0
#
# [2 rows x 31 columns]

# %%
y_test.head(2)
# Out:
# 95141    2
# 6136     2
# Name: readmitted_cat, dtype: int8

# %% [markdown]
# ### <font color=green>min max scaling</font>

# %%
X_train.dtypes
# Out:
# time_in_hospital                int64
# num_lab_procedures              int64
# num_procedures                  int64
# num_medications                 int64
# number_outpatient               int64
# number_emergency                int64
# number_inpatient                int64
# number_diagnoses                int64
# metformin_cat                    int8
# change_cat                       int8
# age_cat                          int8
# max_glu_serum_cat                int8
# race_cat                         int8
# A1Cresult_cat                    int8
# gender_cat                       int8
# admission_source_id_cat          int8
# glyburide_cat                    int8
# diag_3_cat                      int16
# glimepiride_cat                  int8
# repaglinide_cat                  int8
# pioglitazone_cat                 int8
# acarbose_cat                     int8
# nateglinide_cat                  int8
# insulin_cat                      int8
# diag_2_cat                      int16
# diabetesMed_cat                  int8
# admission_type_id_cat            int8
# rosiglitazone_cat                int8
# diag_1_cat                      int16
# glipizide_cat                    int8
# discharge_disposition_id_cat     int8
# dtype: object

# %% [markdown]
# ### <font color=green>before scale</font>

# %%
X_train.describe()
# Out:
#        time_in_hospital  num_lab_procedures  num_procedures  num_medications  \
# count       1506.000000         1506.000000     1506.000000      1506.000000
# mean           3.661355           43.843293        0.725764        11.687251
# std            2.658315           20.649472        1.178360         6.807934
# min            1.000000            1.000000        0.000000         1.000000
# 25%            2.000000           31.000000        0.000000         7.000000
# 50%            3.000000           46.000000        0.000000        10.000000
# 75%            4.000000           59.000000        1.000000        15.000000
# max           14.000000          132.000000        6.000000        65.000000
#
#        number_outpatient  number_emergency  number_inpatient  \
# count        1506.000000       1506.000000       1506.000000
# mean            0.343958          0.502656          1.191235
# std             1.201834          1.362158          2.652263
# min             0.000000          0.000000          0.000000
# 25%             0.000000          0.000000          0.000000
# 50%             0.000000          0.000000          0.000000
# 75%             0.000000          0.000000          1.000000
# max            15.000000         13.000000         21.000000
#
#        number_diagnoses  metformin_cat   change_cat  \
# count       1506.000000    1506.000000  1506.000000
# mean           5.966135       1.098938     0.511952
# std            2.109821       0.334364     0.500023
# min            3.000000       0.000000     0.000000
# 25%            4.000000       1.000000     0.000000
# 50%            6.000000       1.000000     1.000000
# 75%            8.000000       1.000000     1.000000
# max           14.000000       3.000000     1.000000
#
#                    ...               acarbose_cat  nateglinide_cat  \
# count              ...                1506.000000      1506.000000
# mean               ...                   0.000664         0.000664
# std                ...                   0.025768         0.025768
# min                ...                   0.000000         0.000000
# 25%                ...                   0.000000         0.000000
# 50%                ...                   0.000000         0.000000
# 75%                ...                   0.000000         0.000000
# max                ...                   1.000000         1.000000
#
#        insulin_cat   diag_2_cat  diabetesMed_cat  admission_type_id_cat  \
# count  1506.000000  1506.000000      1506.000000            1506.000000
# mean      1.547145   180.519256         0.804781               0.847278
# std       1.049332   140.185534         0.396501               1.333662
# min       0.000000     2.000000         0.000000               0.000000
# 25%       1.000000    86.000000         1.000000               0.000000
# 50%       2.000000   106.000000         1.000000               0.000000
# 75%       2.000000   292.000000         1.000000               1.000000
# max       3.000000   738.000000         1.000000               7.000000
#
#        rosiglitazone_cat   diag_1_cat  glipizide_cat  \
# count        1506.000000  1506.000000    1506.000000
# mean            1.019920   204.867862       1.023904
# std             0.148977   144.058148       0.173185
# min             1.000000     1.000000       0.000000
# 25%             1.000000    73.000000       1.000000
# 50%             1.000000   126.000000       1.000000
# 75%             1.000000   350.000000       1.000000
# max             3.000000   688.000000       3.000000
#
#        discharge_disposition_id_cat
# count                   1506.000000
# mean                       1.841301
# std                        4.899866
# min                        0.000000
# 25%                        0.000000
# 50%                        0.000000
# 75%                        0.000000
# max                       24.000000
#
# [8 rows x 31 columns]

# %%
X_test.describe()
# Out:
#        time_in_hospital  num_lab_procedures  num_procedures  num_medications  \
# count        503.000000          503.000000      503.000000       503.000000
# mean           3.572565           42.596421        0.691849        11.101392
# std            2.715274           21.021952        1.221680         6.929616
# min            1.000000            1.000000        0.000000         1.000000
# 25%            2.000000           28.000000        0.000000         6.000000
# 50%            3.000000           44.000000        0.000000        10.000000
# 75%            4.000000           58.000000        1.000000        15.000000
# max           14.000000          101.000000        6.000000        44.000000
#
#        number_outpatient  number_emergency  number_inpatient  \
# count         503.000000        503.000000        503.000000
# mean            0.320080          0.491054          1.109344
# std             1.051907          1.305604          2.525167
# min             0.000000          0.000000          0.000000
# 25%             0.000000          0.000000          0.000000
# 50%             0.000000          0.000000          0.000000
# 75%             0.000000          0.000000          1.000000
# max             9.000000          8.000000         16.000000
#
#        number_diagnoses  metformin_cat  change_cat  \
# count        503.000000     503.000000  503.000000
# mean           5.793241       1.095427    0.526839
# std            2.041647       0.320046    0.499776
# min            3.000000       1.000000    0.000000
# 25%            4.000000       1.000000    0.000000
# 50%            5.000000       1.000000    1.000000
# 75%            7.000000       1.000000    1.000000
# max            9.000000       3.000000    1.000000
#
#                    ...               acarbose_cat  nateglinide_cat  \
# count              ...                      503.0       503.000000
# mean               ...                        0.0         0.001988
# std                ...                        0.0         0.044588
# min                ...                        0.0         0.000000
# 25%                ...                        0.0         0.000000
# 50%                ...                        0.0         0.000000
# 75%                ...                        0.0         0.000000
# max                ...                        0.0         1.000000
#
#        insulin_cat  diag_2_cat  diabetesMed_cat  admission_type_id_cat  \
# count   503.000000  503.000000       503.000000             503.000000
# mean      1.590457  176.942346         0.783300               0.882704
# std       1.042555  134.140939         0.412407               1.324064
# min       0.000000    2.000000         0.000000               0.000000
# 25%       1.000000   90.000000         1.000000               0.000000
# 50%       2.000000   91.000000         1.000000               0.000000
# 75%       2.000000  287.000000         1.000000               2.000000
# max       3.000000  701.000000         1.000000               6.000000
#
#        rosiglitazone_cat  diag_1_cat  glipizide_cat  \
# count         503.000000  503.000000     503.000000
# mean            1.011928  205.194831       1.025845
# std             0.125673  148.481590       0.158830
# min             0.000000   66.000000       1.000000
# 25%             1.000000   73.000000       1.000000
# 50%             1.000000  125.000000       1.000000
# 75%             1.000000  350.000000       1.000000
# max             2.000000  707.000000       2.000000
#
#        discharge_disposition_id_cat
# count                    503.000000
# mean                       2.103380
# std                        5.303653
# min                        0.000000
# 25%                        0.000000
# 50%                        0.000000
# 75%                        0.000000
# max                       24.000000
#
# [8 rows x 31 columns]

# %%
scaler = MinMaxScaler()
X_train = pd.DataFrame(scaler.fit_transform(X_train), columns=X_features)
X_test = pd.DataFrame(scaler.transform(X_test), columns = X_features)

# %% [markdown]
# ### <font color=green>after scale</font>

# %%
X_train.iloc[:,:20].describe()
# Out:
#        time_in_hospital  num_lab_procedures  num_procedures  num_medications  \
# count       1506.000000         1506.000000     1506.000000      1506.000000
# mean           0.204720            0.327048        0.120961         0.166988
# std            0.204486            0.157630        0.196393         0.106374
# min            0.000000            0.000000        0.000000         0.000000
# 25%            0.076923            0.229008        0.000000         0.093750
# 50%            0.153846            0.343511        0.000000         0.140625
# 75%            0.230769            0.442748        0.166667         0.218750
# max            1.000000            1.000000        1.000000         1.000000
#
#        number_outpatient  number_emergency  number_inpatient  \
# count        1506.000000       1506.000000       1506.000000
# mean            0.022931          0.038666          0.056725
# std             0.080122          0.104781          0.126298
# min             0.000000          0.000000          0.000000
# 25%             0.000000          0.000000          0.000000
# 50%             0.000000          0.000000          0.000000
# 75%             0.000000          0.000000          0.047619
# max             1.000000          1.000000          1.000000
#
#        number_diagnoses  metformin_cat   change_cat      age_cat  \
# count       1506.000000    1506.000000  1506.000000  1506.000000
# mean           0.269649       0.366313     0.511952     0.852258
# std            0.191802       0.111455     0.500023     0.263351
# min            0.000000       0.000000     0.000000     0.000000
# 25%            0.090909       0.333333     0.000000     0.500000
# 50%            0.272727       0.333333     1.000000     1.000000
# 75%            0.454545       0.333333     1.000000     1.000000
# max            1.000000       1.000000     1.000000     1.000000
#
#        max_glu_serum_cat     race_cat  A1Cresult_cat   gender_cat  \
# count        1506.000000  1506.000000    1506.000000  1506.000000
# mean            0.658256     0.351428       0.597167     0.347278
# std             0.071394     0.262646       0.192232     0.476263
# min             0.000000     0.000000       0.000000     0.000000
# 25%             0.666667     0.000000       0.333333     0.000000
# 50%             0.666667     0.500000       0.666667     0.000000
# 75%             0.666667     0.500000       0.666667     1.000000
# max             1.000000     1.000000       1.000000     1.000000
#
#        admission_source_id_cat  glyburide_cat   diag_3_cat  glimepiride_cat  \
# count              1506.000000    1506.000000  1506.000000      1506.000000
# mean                  0.379008       0.011288     0.293742         0.504316
# std                   0.261581       0.082760     0.221505         0.049730
# min                   0.000000       0.000000     0.000000         0.000000
# 25%                   0.000000       0.000000     0.115584         0.500000
# 50%                   0.571429       0.000000     0.222078         0.500000
# 75%                   0.571429       0.000000     0.440260         0.500000
# max                   1.000000       1.000000     1.000000         1.000000
#
#        repaglinide_cat
# count      1506.000000
# mean          0.002324
# std           0.042683
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max           1.000000

# %%
X_train.iloc[:,21:40].describe()
# Out:
#        acarbose_cat  nateglinide_cat  insulin_cat   diag_2_cat  \
# count   1506.000000      1506.000000  1506.000000  1506.000000
# mean       0.000664         0.000664     0.515715     0.242553
# std        0.025768         0.025768     0.349777     0.190469
# min        0.000000         0.000000     0.000000     0.000000
# 25%        0.000000         0.000000     0.333333     0.114130
# 50%        0.000000         0.000000     0.666667     0.141304
# 75%        0.000000         0.000000     0.666667     0.394022
# max        1.000000         1.000000     1.000000     1.000000
#
#        diabetesMed_cat  admission_type_id_cat  rosiglitazone_cat   diag_1_cat  \
# count      1506.000000            1506.000000        1506.000000  1506.000000
# mean          0.804781               0.121040           0.009960     0.296751
# std           0.396501               0.190523           0.074489     0.209692
# min           0.000000               0.000000           0.000000     0.000000
# 25%           1.000000               0.000000           0.000000     0.104803
# 50%           1.000000               0.000000           0.000000     0.181951
# 75%           1.000000               0.142857           0.000000     0.508006
# max           1.000000               1.000000           1.000000     1.000000
#
#        glipizide_cat  discharge_disposition_id_cat
# count    1506.000000                   1506.000000
# mean        0.341301                      0.076721
# std         0.057728                      0.204161
# min         0.000000                      0.000000
# 25%         0.333333                      0.000000
# 50%         0.333333                      0.000000
# 75%         0.333333                      0.000000
# max         1.000000                      1.000000

# %%
y_train.describe()
# Out:
# count    1506.000000
# mean        1.442231
# std         0.696204
# min         0.000000
# 25%         1.000000
# 50%         2.000000
# 75%         2.000000
# max         2.000000
# Name: readmitted_cat, dtype: float64

# %%
X_test.shape
# Out:
# (503, 31)

# %%
X_test.iloc[:,:20].describe()
# Out:
#        time_in_hospital  num_lab_procedures  num_procedures  num_medications  \
# count        503.000000          503.000000      503.000000       503.000000
# mean           0.197890            0.317530        0.115308         0.157834
# std            0.208867            0.160473        0.203613         0.108275
# min            0.000000            0.000000        0.000000         0.000000
# 25%            0.076923            0.206107        0.000000         0.078125
# 50%            0.153846            0.328244        0.000000         0.140625
# 75%            0.230769            0.435115        0.166667         0.218750
# max            1.000000            0.763359        1.000000         0.671875
#
#        number_outpatient  number_emergency  number_inpatient  \
# count         503.000000        503.000000        503.000000
# mean            0.021339          0.037773          0.052826
# std             0.070127          0.100431          0.120246
# min             0.000000          0.000000          0.000000
# 25%             0.000000          0.000000          0.000000
# 50%             0.000000          0.000000          0.000000
# 75%             0.000000          0.000000          0.047619
# max             0.600000          0.615385          0.761905
#
#        number_diagnoses  metformin_cat  change_cat     age_cat  \
# count        503.000000     503.000000  503.000000  503.000000
# mean           0.253931       0.365142    0.526839    0.849901
# std            0.185604       0.106682    0.499776    0.256072
# min            0.000000       0.333333    0.000000    0.000000
# 25%            0.090909       0.333333    0.000000    0.500000
# 50%            0.181818       0.333333    1.000000    1.000000
# 75%            0.363636       0.333333    1.000000    1.000000
# max            0.545455       1.000000    1.000000    1.000000
#
#        max_glu_serum_cat    race_cat  A1Cresult_cat  gender_cat  \
# count         503.000000  503.000000     503.000000  503.000000
# mean            0.655401    0.363320       0.604374    0.359841
# std             0.076478    0.247158       0.188441    0.480431
# min             0.000000    0.000000       0.000000    0.000000
# 25%             0.666667    0.000000       0.666667    0.000000
# 50%             0.666667    0.500000       0.666667    0.000000
# 75%             0.666667    0.500000       0.666667    1.000000
# max             1.000000    1.000000       1.000000    1.000000
#
#        admission_source_id_cat  glyburide_cat  diag_3_cat  glimepiride_cat  \
# count               503.000000     503.000000  503.000000       503.000000
# mean                  0.362823       0.006958    0.286861         0.507952
# std                   0.265828       0.058631    0.215587         0.062615
# min                   0.000000       0.000000    0.000000         0.500000
# 25%                   0.000000       0.000000    0.115584         0.500000
# 50%                   0.571429       0.000000    0.222078         0.500000
# 75%                   0.571429       0.000000    0.427273         0.500000
# max                   0.571429       0.500000    0.993506         1.000000
#
#        repaglinide_cat
# count            503.0
# mean               0.0
# std                0.0
# min                0.0
# 25%                0.0
# 50%                0.0
# 75%                0.0
# max                0.0

# %%
X_test.iloc[:,21:40].describe()
# Out:
#        acarbose_cat  nateglinide_cat  insulin_cat  diag_2_cat  \
# count         503.0       503.000000   503.000000  503.000000
# mean            0.0         0.001988     0.530152    0.237693
# std             0.0         0.044588     0.347518    0.182257
# min             0.0         0.000000     0.000000    0.000000
# 25%             0.0         0.000000     0.333333    0.119565
# 50%             0.0         0.000000     0.666667    0.120924
# 75%             0.0         0.000000     0.666667    0.387228
# max             0.0         1.000000     1.000000    0.949728
#
#        diabetesMed_cat  admission_type_id_cat  rosiglitazone_cat  diag_1_cat  \
# count       503.000000             503.000000         503.000000  503.000000
# mean          0.783300               0.126101           0.005964    0.297227
# std           0.412407               0.189152           0.062836    0.216130
# min           0.000000               0.000000          -0.500000    0.094614
# 25%           1.000000               0.000000           0.000000    0.104803
# 50%           1.000000               0.000000           0.000000    0.180495
# 75%           1.000000               0.285714           0.000000    0.508006
# max           1.000000               0.857143           0.500000    1.027656
#
#        glipizide_cat  discharge_disposition_id_cat
# count     503.000000                    503.000000
# mean        0.341948                      0.087641
# std         0.052943                      0.220986
# min         0.333333                      0.000000
# 25%         0.333333                      0.000000
# 50%         0.333333                      0.000000
# 75%         0.333333                      0.000000
# max         0.666667                      1.000000

# %%
y_test.describe()
# Out:
# count    503.000000
# mean       1.429423
# std        0.713060
# min        0.000000
# 25%        1.000000
# 50%        2.000000
# 75%        2.000000
# max        2.000000
# Name: readmitted_cat, dtype: float64

# %% [markdown]
# <a id='SVM'></a>

# %% [markdown]
# ### <font color=green> Baseline Categorical</font>

# %%
# %%time
from sklearn.dummy import DummyClassifier

d_major = DummyClassifier(strategy='most_frequent').fit(X_train, y_train)

print('train accuracy: {:.2f}'.format(d_major.score(X_train, y_train)))
print('test accuracy: {:.2f}'.format(d_major.score(X_test, y_test)))
# Out:
# train accuracy: 0.56
# test accuracy: 0.56
# CPU times: user 4.43 ms, sys: 16 µs, total: 4.45 ms
# Wall time: 3.64 ms

# %%
plot_confusion(d_major, 'Categorical Dummy Classifier', X_test, y_test)
# Out:
# <img src="data:image/png;base64,..." width="599.2307912104236">
# Micro-averaged precision = 0.56 (treat instances equally)
# Macro-averaged precision = 0.19 (treat classes equally)
# Micro-averaged f1 = 0.56 (treat instances equally)
# Macro-averaged f1 = 0.24 (treat classes equally)
#              precision    recall  f1-score   support
#
#         <30       0.00      0.00      0.00        66
#         >30       0.00      0.00      0.00       155
#          NO       0.56      1.00      0.72       282
#
# avg / total       0.31      0.56      0.40       503
# /home/lam/anaconda2/envs/my_env3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/lam/anaconda2/envs/my_env3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/lam/anaconda2/envs/my_env3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
# %%time
clf = LinearSVC(verbose=True).fit(X_train, y_train)

print('training accuracy: {:.2f}'.format(clf.score(X_train, y_train)))
print('test accuracy: {:.2f}'.format(clf.score(X_test, y_test)))
plot_confusion(clf, 'Categorical Linear Kernel', X_test, y_test)
# Out:
# [LibLinear]training accuracy: 0.63
# test accuracy: 0.63
# <div id='c6d4a0e8-2250-40eb-8c76-9169edcb04c3'></div>
# Micro-averaged precision = 0.63 (treat instances equally)
# Macro-averaged precision = 0.55 (treat classes equally)
# Micro-averaged f1 = 0.63 (treat instances equally)
# Macro-averaged f1 = 0.44 (treat classes equally)
#              precision    recall  f1-score   support
#
#         <30       0.47      0.12      0.19        66
#         >30       0.52      0.28      0.36       155
#          NO       0.66      0.94      0.77       282
#
# avg / total       0.59      0.63      0.57       503
#
# CPU times: user 300 ms, sys: 12 ms, total: 312 ms
# Wall time: 144 ms

# %% [markdown]
# ### <font color=green>SVM optimise over accuracy</font>

# %%
# %%time
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import roc_auc_score

clf = SVC() 

grid_values = [
  {'C': [0.1, 1, 10, 100, 1000], 'kernel':['linear']}, 
    {'C': [0.1, 1, 10, 100, 1000], 'gamma': [0.001, 0.01, 0.05, 0.1, 1, 10, 100], 
     'kernel':['rbf', 'sigmoid']},
    {'C': [0.1, 1, 10, 100, 1000], 'gamma': [0.001, 0.01, 0.05, 0.1, 1, 10, 100],
     'degree':[2, 3, 4, 5], 'kernel': ['poly']}
 ]

grid_clf_acc = GridSearchCV(clf, param_grid = grid_values, n_jobs= 4)
grid_clf_acc.fit(X_train, y_train)
y_decision_fn_scores_acc = grid_clf_acc.decision_function(X_test) 

print('Grid best parameter (max. accuracy): ', grid_clf_acc.best_params_)
print('Grid best score (accuracy): ', grid_clf_acc.best_score_)

# %%
pd.DataFrame(grid_clf_acc.cv_results_).sort_values(by=['mean_test_score'], ascending=False).iloc[:,2:8]

# %%
plot_confusion(grid_clf_acc, 'Categorical Grid Search Linear', X_test,y_test)

# %%
# precision recall curve only for binary class

# %% [markdown]
# <a id='hot'></a>

# %% [markdown]
# ## <font color=Orange>One Hot</font>

# %%
X_train, X_test, y_train, y_test = train_test_split(
    df[X_features], df['readmitted_cat'] , random_state = 0)

# %%
X_train.dtypes

# %%
X_train.describe()

# %%
X_test.describe()

# %%
to_num

# %% [markdown]
# ### <font color=orange>scale numerical</font>

# %%
scaler = MinMaxScaler()
X_train_hot = pd.DataFrame(scaler.fit_transform(X_train[to_num]), columns=to_num)
X_test_hot = pd.DataFrame(scaler.transform(X_test[to_num]), columns = to_num)

# %%
from sklearn.preprocessing import OneHotEncoder
hot_features = list(set(X_features) - set(to_num))
hot_features

# %%
enc = OneHotEncoder()
enc.fit(df[hot_features])
enc.n_values_

# %%
enc.feature_indices_

# %% [markdown]
# ### <font color=orange> convert to one hot </font>

# %%
X_train_hot = pd.concat([X_train_hot, \
                         pd.DataFrame(enc.transform(X_train[hot_features]).toarray())], axis=1)

X_test_hot = pd.concat([X_test_hot, \
                         pd.DataFrame(enc.transform(X_test[hot_features]).toarray())], axis=1)

# %%
X_train_hot.head(2)

# %%
X_test_hot.head(2)

# %% [markdown]
# ### <font color=orange> SVM one hot</font>

# %%
# %%time
from sklearn.dummy import DummyClassifier

d_major = DummyClassifier(strategy='most_frequent').fit(X_train_hot, y_train)

print('train accuracy: {:.2f}'.format(d_major.score(X_train_hot, y_train)))
print('test accuracy: {:.2f}'.format(d_major.score(X_test_hot, y_test)))
plot_confusion(d_major, 'One Hot Dummy Classifier', X_test_hot, y_test)

# %%
# %%time
clf = LinearSVC(verbose=True).fit(X_train_hot, y_train)

print('training accuracy: {:.2f}'.format(clf.score(X_train_hot, y_train)))
print('test accuracy: {:.2f}'.format(clf.score(X_test_hot, y_test)))
plot_confusion(clf, 'One Hot Linear Kernel', X_test_hot, y_test )

# %% [markdown]
# ### <font color=orange>SVM optimise over accuracy</font>

# %%
# %%time
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import roc_auc_score

clf = SVC() 

grid_values = [
  {'C': [0.1, 1, 10, 100, 1000], 'kernel':['linear', 'sigmoid']}, 
    {'C': [0.1, 1, 10, 100, 1000], 'gamma': [0.001, 0.01, 0.05, 0.1, 1, 10, 100], 'kernel':['rbf']},
    {'C': [0.1, 1, 10, 100, 1000], 'degree':[2, 3, 4, 5], 'kernel': ['poly']}
 ]

grid_clf_acc = GridSearchCV(clf, param_grid = grid_values, n_jobs= 4 )
grid_clf_acc.fit(X_train_hot, y_train)
y_decision_fn_scores_acc = grid_clf_acc.decision_function(X_test_hot) 

print('Grid best parameter (max. accuracy): ', grid_clf_acc.best_params_)
print('Grid best score (accuracy): ', grid_clf_acc.best_score_)

# %%
pd.DataFrame(grid_clf_acc.cv_results_).sort_values(by=['mean_test_score'], ascending=False).iloc[:,2:8]

# %%
plot_confusion(grid_clf_acc, 'One Hot Grid Search Linear', X_test_hot, y_test)
