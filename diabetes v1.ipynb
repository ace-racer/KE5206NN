# %% [markdown]
# ## Diabetes

# %%
# %matplotlib notebook
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from tqdm import tqdm

df = pd.read_csv("diabetic_data.csv", dtype='category').iloc[:100,2:]
df.shape
# Out:
# (100, 48)

# %%
df.head(5)
# Out:
#               race  gender      age weight admission_type_id  \
# 0        Caucasian  Female   [0-10)      ?                 6
# 1        Caucasian  Female  [10-20)      ?                 1
# 2  AfricanAmerican  Female  [20-30)      ?                 1
# 3        Caucasian    Male  [30-40)      ?                 1
# 4        Caucasian    Male  [40-50)      ?                 1
#
#   discharge_disposition_id admission_source_id time_in_hospital payer_code  \
# 0                       25                   1                1          ?
# 1                        1                   7                3          ?
# 2                        1                   7                2          ?
# 3                        1                   7                2          ?
# 4                        1                   7                1          ?
#
#           medical_specialty    ...     citoglipton insulin  \
# 0  Pediatrics-Endocrinology    ...              No      No
# 1                         ?    ...              No      Up
# 2                         ?    ...              No      No
# 3                         ?    ...              No      Up
# 4                         ?    ...              No  Steady
#
#   glyburide-metformin glipizide-metformin glimepiride-pioglitazone  \
# 0                  No                  No                       No
# 1                  No                  No                       No
# 2                  No                  No                       No
# 3                  No                  No                       No
# 4                  No                  No                       No
#
#   metformin-rosiglitazone metformin-pioglitazone change diabetesMed readmitted
# 0                      No                     No     No          No         NO
# 1                      No                     No     Ch         Yes        >30
# 2                      No                     No     No         Yes         NO
# 3                      No                     No     Ch         Yes         NO
# 4                      No                     No     Ch         Yes         NO
#
# [5 rows x 48 columns]

# %%
to_num = ['time_in_hospital', 'num_lab_procedures', 'num_procedures',
         'num_medications', 'number_outpatient', 'number_emergency',
         'number_inpatient', 'number_diagnoses']

# %% [markdown]
# ### remove missing

# %%
df = df.drop(columns=['weight', 'payer_code', 'medical_specialty'])
df.head(2)
# Out:
#         race  gender      age admission_type_id discharge_disposition_id  \
# 0  Caucasian  Female   [0-10)                 6                       25
# 1  Caucasian  Female  [10-20)                 1                        1
#
#   admission_source_id time_in_hospital num_lab_procedures num_procedures  \
# 0                   1                1                 41              0
# 1                   7                3                 59              0
#
#   num_medications    ...     citoglipton insulin glyburide-metformin  \
# 0               1    ...              No      No                  No
# 1              18    ...              No      Up                  No
#
#   glipizide-metformin glimepiride-pioglitazone metformin-rosiglitazone  \
# 0                  No                       No                      No
# 1                  No                       No                      No
#
#   metformin-pioglitazone change diabetesMed readmitted
# 0                     No     No          No         NO
# 1                     No     Ch         Yes        >30
#
# [2 rows x 45 columns]

# %% [markdown]
# ### split

# %%
X_train, X_test, y_train, y_test = train_test_split(
    df[df.columns[:-1]], df[df.columns[-1:]] , random_state = 0)

# %%
X_train.shape
# Out:
# (75, 44)

# %%
X_test.shape
# Out:
# (25, 44)

# %%
y_train.dtypes
# Out:
# readmitted    category
# dtype: object

# %%
X_train.dtypes
# Out:
# race                        category
# gender                      category
# age                         category
# admission_type_id           category
# discharge_disposition_id    category
# admission_source_id         category
# time_in_hospital            category
# num_lab_procedures          category
# num_procedures              category
# num_medications             category
# number_outpatient           category
# number_emergency            category
# number_inpatient            category
# diag_1                      category
# diag_2                      category
# diag_3                      category
# number_diagnoses            category
# max_glu_serum               category
# A1Cresult                   category
# metformin                   category
# repaglinide                 category
# nateglinide                 category
# chlorpropamide              category
# glimepiride                 category
# acetohexamide               category
# glipizide                   category
# glyburide                   category
# tolbutamide                 category
# pioglitazone                category
# rosiglitazone               category
# acarbose                    category
# miglitol                    category
# troglitazone                category
# tolazamide                  category
# examide                     category
# citoglipton                 category
# insulin                     category
# glyburide-metformin         category
# glipizide-metformin         category
# glimepiride-pioglitazone    category
# metformin-rosiglitazone     category
# metformin-pioglitazone      category
# change                      category
# diabetesMed                 category
# dtype: object

# %% [markdown]
# ### scaling

# %%
scaler = MinMaxScaler()
for n in to_num:
    X_train[n] = X_train[n].astype('int')
    X_test[n] = X_test[n].astype('int')
    X_train[n] = scaler.fit_transform(X_train[n].reshape(-1, 1))
    X_test[n] = scaler.fit_transform(X_test[n].reshape(-1, 1))
# Out:
# /home/lam/anaconda2/envs/my_env3/lib/python3.6/site-packages/ipykernel_launcher.py:5: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   """
# /home/lam/anaconda2/envs/my_env3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)
# /home/lam/anaconda2/envs/my_env3/lib/python3.6/site-packages/ipykernel_launcher.py:6: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead

# %%
X_features = to_num
for c in X_train.columns:
    if X_train[c].dtypes != 'float64':
        X_train[c+'_cat'] = X_train[c].cat.codes        
        X_test[c+'_cat'] = X_test[c].cat.codes
        X_features += [c+'_cat']

# %%
y_train['readmitted' + '_cat'] = y_train['readmitted'].cat.codes        
y_test['readmitted' + '_cat'] = y_test['readmitted'].cat.codes

# %%
y_train.columns
# Out:
# Index(['readmitted', 'readmitted_cat'], dtype='object')

# %%
X_train[X_features].dtypes
# Out:
# time_in_hospital                float64
# num_lab_procedures              float64
# num_procedures                  float64
# num_medications                 float64
# number_outpatient               float64
# number_emergency                float64
# number_inpatient                float64
# number_diagnoses                float64
# race_cat                           int8
# gender_cat                         int8
# age_cat                            int8
# admission_type_id_cat              int8
# discharge_disposition_id_cat       int8
# admission_source_id_cat            int8
# diag_1_cat                        int16
# diag_2_cat                        int16
# diag_3_cat                        int16
# max_glu_serum_cat                  int8
# A1Cresult_cat                      int8
# metformin_cat                      int8
# repaglinide_cat                    int8
# nateglinide_cat                    int8
# chlorpropamide_cat                 int8
# glimepiride_cat                    int8
# acetohexamide_cat                  int8
# glipizide_cat                      int8
# glyburide_cat                      int8
# tolbutamide_cat                    int8
# pioglitazone_cat                   int8
# rosiglitazone_cat                  int8
# acarbose_cat                       int8
# miglitol_cat                       int8
# troglitazone_cat                   int8
# tolazamide_cat                     int8
# examide_cat                        int8
# citoglipton_cat                    int8
# insulin_cat                        int8
# glyburide-metformin_cat            int8
# glipizide-metformin_cat            int8
# glimepiride-pioglitazone_cat       int8
# metformin-rosiglitazone_cat        int8
# metformin-pioglitazone_cat         int8
# change_cat                         int8
# diabetesMed_cat                    int8
# dtype: object

# %%
X_train[X_features].head(2)
# Out:
#     time_in_hospital  num_lab_procedures  num_procedures  num_medications  \
# 48          0.416667            0.863014        0.833333         0.692308
# 6           0.250000            0.931507        0.166667         0.769231
#
#     number_outpatient  number_emergency  number_inpatient  number_diagnoses  \
# 48                0.0               0.0               0.0              1.00
# 6                 0.0               0.0               0.0              0.75
#
#     race_cat  gender_cat       ...         examide_cat  citoglipton_cat  \
# 48         3           1       ...                   0                0
# 6          3           1       ...                   0                0
#
#     insulin_cat  glyburide-metformin_cat  glipizide-metformin_cat  \
# 48            3                        1                        0
# 6             2                        1                        0
#
#     glimepiride-pioglitazone_cat  metformin-rosiglitazone_cat  \
# 48                             0                            0
# 6                              0                            0
#
#     metformin-pioglitazone_cat  change_cat  diabetesMed_cat
# 48                           0           0                1
# 6                            0           0                1
#
# [2 rows x 44 columns]

# %%
X_train[X_features].describe()
# Out:
#        time_in_hospital  num_lab_procedures  num_procedures  num_medications  \
# count         75.000000           75.000000       75.000000        75.000000
# mean           0.324444            0.602740        0.253333         0.534872
# std            0.253198            0.217097        0.270357         0.206752
# min            0.000000            0.000000        0.000000         0.000000
# 25%            0.166667            0.458904        0.000000         0.384615
# 50%            0.250000            0.616438        0.166667         0.576923
# 75%            0.500000            0.767123        0.333333         0.692308
# max            1.000000            1.000000        1.000000         1.000000
#
#        number_outpatient  number_emergency  number_inpatient  \
# count          75.000000         75.000000         75.000000
# mean            0.013333          0.026667          0.106667
# std             0.115470          0.162192          0.236719
# min             0.000000          0.000000          0.000000
# 25%             0.000000          0.000000          0.000000
# 50%             0.000000          0.000000          0.000000
# 75%             0.000000          0.000000          0.000000
# max             1.000000          1.000000          1.000000
#
#        number_diagnoses   race_cat  gender_cat       ...         examide_cat  \
# count         75.000000  75.000000   75.000000       ...                75.0
# mean           0.760000   2.413333    0.480000       ...                 0.0
# std            0.265372   1.186561    0.502964       ...                 0.0
# min            0.000000   0.000000    0.000000       ...                 0.0
# 25%            0.625000   1.000000    0.000000       ...                 0.0
# 50%            0.875000   3.000000    0.000000       ...                 0.0
# 75%            1.000000   3.000000    1.000000       ...                 0.0
# max            1.000000   5.000000    1.000000       ...                 0.0
#
#        citoglipton_cat  insulin_cat  glyburide-metformin_cat  \
# count             75.0    75.000000                     75.0
# mean               0.0     1.493333                      1.0
# std                0.0     0.963851                      0.0
# min                0.0     0.000000                      1.0
# 25%                0.0     1.000000                      1.0
# 50%                0.0     2.000000                      1.0
# 75%                0.0     2.000000                      1.0
# max                0.0     3.000000                      1.0
#
#        glipizide-metformin_cat  glimepiride-pioglitazone_cat  \
# count                     75.0                          75.0
# mean                       0.0                           0.0
# std                        0.0                           0.0
# min                        0.0                           0.0
# 25%                        0.0                           0.0
# 50%                        0.0                           0.0
# 75%                        0.0                           0.0
# max                        0.0                           0.0
#
#        metformin-rosiglitazone_cat  metformin-pioglitazone_cat  change_cat  \
# count                         75.0                        75.0    75.00000
# mean                           0.0                         0.0     0.44000
# std                            0.0                         0.0     0.49973
# min                            0.0                         0.0     0.00000
# 25%                            0.0                         0.0     0.00000
# 50%                            0.0                         0.0     0.00000
# 75%                            0.0                         0.0     1.00000
# max                            0.0                         0.0     1.00000
#
#        diabetesMed_cat
# count         75.00000
# mean           0.92000
# std            0.27312
# min            0.00000
# 25%            1.00000
# 50%            1.00000
# 75%            1.00000
# max            1.00000
#
# [8 rows x 44 columns]

# %% [markdown]
# ## RBF kernel SVM with min max scaling

# %%
clf = SVC(C=10).fit(X_train[X_features], y_train['readmitted_cat'])

print('training accuracy: {:.2f}'.format(clf.score(X_train[X_features], y_train['readmitted_cat'])))
print('test accuracy: {:.2f}'.format(clf.score(X_test[X_features], y_test['readmitted_cat'])))
# Out:
# training accuracy: 1.00
# test accuracy: 0.44

# %% [markdown]
# ### optimize over accuracy

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import roc_auc_score

clf = SVC()
grid_values = [
  {'C': [1, 10, 100, 1000], 'kernel': ['linear']},
  {'C': [1, 10, 100, 1000], 'gamma': [0.001, 0.01, 0.05, 0.1, 1, 10, 100], 'kernel': ['rbf']},
 ]

grid_clf_acc = GridSearchCV(clf, param_grid = grid_values)
grid_clf_acc.fit(X_train[X_features], y_train['readmitted_cat'])
y_decision_fn_scores_acc = grid_clf_acc.decision_function(X_test[X_features]) 

print('Grid best parameter (max. accuracy): ', grid_clf_acc.best_params_)
print('Grid best score (accuracy): ', grid_clf_acc.best_score_)
# Out:
# Grid best parameter (max. accuracy):  {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# Grid best score (accuracy):  0.6133333333333333

# %%
y_decision_fn_scores_acc
# Out:
# array([[-0.14198852,  0.95709511,  2.18489341],
#        [-0.29439909,  2.30454117,  0.98985793],
#        [-0.23067366,  2.1446654 ,  1.08600826],
#        [ 2.03050349,  1.01198494, -0.04248843],
#        [-0.470289  ,  2.5       ,  0.970289  ],
#        [-0.2306963 ,  2.14459114,  1.08610516],
#        [-0.36584018,  2.39851604,  0.96732415],
#        [-0.23067366,  2.1446654 ,  1.08600826],
#        [-0.23124447,  2.1469529 ,  1.08429157],
#        [-0.27111444,  1.00493381,  2.26618063],
#        [-0.23691429,  2.12265137,  1.11426292],
#        [-0.25662168,  2.248443  ,  1.00817867],
#        [-0.26419365,  1.02876354,  2.23543011],
#        [-0.23576972,  2.3309608 ,  0.90480892],
#        [-0.18410351,  2.13806134,  1.04604218],
#        [-0.23067338,  2.14466479,  1.08600858],
#        [-0.26297771,  2.25103883,  1.01193888],
#        [-0.23097299,  2.14586439,  1.0851086 ],
#        [-0.23545723,  2.12811103,  1.1073462 ],
#        [-0.38628789,  1.14049775,  2.24579014],
#        [-0.22672427,  2.15244918,  1.0742751 ],
#        [-0.23093055,  2.14570005,  1.0852305 ],
#        [-0.16885051,  2.11362274,  1.05522778],
#        [-0.23127941,  2.14708718,  1.08419223],
#        [-0.23067366,  2.1446654 ,  1.08600826]])

# %%
# precision recall curve only for binary class
